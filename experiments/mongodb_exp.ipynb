# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://anasbelfathi247_db_user:jbJuSnBsVXWWpVwW@cluster0.sdxnan9.mongodb.net/?appName=Cluster0")

# %%
db = client["ecom_db"]

collection = db["orders"]

print("connected to mongo db")
# Out:
# connected to mongo db

# %%
order = {
    'name' : "Men Casual Shirt",
    'price' : 999,
    'category' : 'men'
}

collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('6a357cef146884330ab654c2'), acknowledged=True)

# %%
products = [
     {
    'name' : "Jeans",
    'price' : 100,
    'category' : 'men'
},
{
    'name' : "Surviette",
    'price' : 150,
    'category' : 'men'
},
{
    'name' : "ssofitma",
    'price' : 10,
    'category' : 'men'
}
]
collection.insert_many(products)
print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6a354330146884330ab654be'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('6a3543d7146884330ab654bf'), 'name': 'Jeans', 'price': 100, 'category': 'men'}
# {'_id': ObjectId('6a3543d7146884330ab654c0'), 'name': 'Surviette', 'price': 150, 'category': 'men'}
# {'_id': ObjectId('6a3543d7146884330ab654c1'), 'name': 'ssofitma', 'price': 10, 'category': 'men'}

# %%
product = collection.find_one({"name": "Jeans"})
print(product)
# Out:
# {'_id': ObjectId('6a3543d7146884330ab654bf'), 'name': 'Jeans', 'price': 100, 'category': 'men'}

# %% [markdown]
# Update

# %%
collection.delete_one({"name": "Jeans"})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000000b6'), 'opTime': {'ts': Timestamp(1781889971, 2), 't': 182}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1781889971, 2), 'signature': {'hash': b'\xc2\xa1\xb8\x1d\x08_\x8b\x19\x1b\xa3d^\xa0\xff\x8b\xf8\xa5t_\xcc', 'keyId': 7606448357514412047}}, 'operationTime': Timestamp(1781889971, 2)}, acknowledged=True)
